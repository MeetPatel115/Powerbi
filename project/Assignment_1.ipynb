# %%
#!pip install yahoo_fin

# %% [markdown]
# ## Importing Library

# %%
# importing Library
import pandas as pd
import numpy as np
import yfinance as yf
from yahoo_fin.stock_info import get_data
from yahoo_fin import news as yahoo_news
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# get the Dataset
data=pd.read_csv('China_compnanies.csv')

# %%
data.head()
# Out:
#                        Company Name,Abbreviation
# 0             Alibaba Group Holding Limited,BABA
# 1                 Tencent Holdings Limited,TCEHY
# 2    China Mobile Communications Corporation,CHL
# 3  Industrial and Commercial Bank of China,IDCBY
# 4      China Construction Bank Corporation,CICHY

# %%
# getting company name from the given Dataset
data[['Company_Name', 'Abbreviation']] = data['Company Name,Abbreviation'].str.split(',',n=1, expand=True)

# %%
# change the column name of the dataset
data.drop(columns=['Company Name,Abbreviation'],inplace=True)

# %%
# copy Data on the Root dataset
data.head()
# Out:
#                               Company_Name Abbreviation
# 0            Alibaba Group Holding Limited         BABA
# 1                 Tencent Holdings Limited        TCEHY
# 2  China Mobile Communications Corporation          CHL
# 3  Industrial and Commercial Bank of China        IDCBY
# 4      China Construction Bank Corporation        CICHY

# %% [markdown]
# ## The Dataset of Top 50 companies of the China are created

# %%
def get_news2(com_name, number_of_news=30):
    try:

    
        news_of_company = yahoo_news.get_yf_rss(com_name) # The news of the company get and store in news of company
        news_of_company = news_of_company[:number_of_news] # the number of news fetch from the api
        news_data = [(article['title'], article['summary'], article['published']) for article in news_of_company]
        dataset_news = pd.DataFrame(news_data, columns=['Title', 'Content','published_date']) # creating the datsset
        dataset_news['Company'] = com_name # store the abbreivation
        return dataset_news
    except Exception as e:
       
        return None

# %%
# crating the dataset of ever company 
news_dataset = []
for company_abrevation in data['Abbreviation']:
    company_news = get_news2(company_abrevation)
    if company_news is not None:
        news_dataset.append(company_news)
        

all_news_df = pd.concat(news_dataset)

# %%
#The dataset is form  
all_news_df
# Out:
#                                                 Title  \
# 0   Chinese start-up Moonshot AI raises US$1 billi...
# 1   Alibaba Stock Falls as Chinese Markets Disappo...
# 2   Big Pension Bought Up NYCB Stock Right Before ...
# 3      25 Most Valuable Tech Companies Outside The US
# 4           No Clear Sign of a Turnaround for Alibaba
# ..                                                ...
# 15  Country Garden to Make CNY3.07 Billion Disposa...
# 16  Country Garden sells stake in Dalian Wanda uni...
# 17  UPDATE 1-Country Garden has remitted funds to ...
# 18  Country Garden repays US$111 million bond in f...
# 19  Trending tickers: Arm | Jumia | Country Garden...
#
#                                               Content  \
# 0   Chinese artificial intelligence start-up Moons...
# 1   Shanghai stocks advanced on Monday but posted ...
# 2   A New York pension bought up shares of New Yor...
# 3   In this article, we will take a look at the 25...
# 4   Taobao and TMall Group's troubles overshadow g...
# ..                                                ...
# 15  Chinese property giant Country Garden will sel...
# 16  HONG KONG (Reuters) -China's embattled Country...
# 17  Embattled Chinese developer Country Garden Hol...
# 18  Embattled property developer Country Garden Ho...
# 19  The latest investor updates on stocks that are...
#
#                      published_date  Company
# 0   Tue, 20 Feb 2024 09:30:00 +0000     BABA
# 1   Mon, 19 Feb 2024 11:42:00 +0000     BABA
# 2   Mon, 19 Feb 2024 08:15:00 +0000     BABA
# 3   Fri, 16 Feb 2024 20:47:36 +0000     BABA
# 4   Fri, 16 Feb 2024 13:00:03 +0000     BABA
# ..                              ...      ...
# 15  Thu, 14 Dec 2023 01:16:00 +0000  2007.HK
# 16  Thu, 14 Dec 2023 00:37:15 +0000  2007.HK
# 17  Wed, 13 Dec 2023 12:00:25 +0000  2007.HK
# 18  Wed, 13 Dec 2023 09:30:00 +0000  2007.HK
# 19  Thu, 23 Nov 2023 09:59:54 +0000  2007.HK
#
# [226 rows x 4 columns]

# %%
# Convert the 'date_str' column to datetime format
all_news_df['date'] = pd.to_datetime(all_news_df['published_date'], format='%a, %d %b %Y %H:%M:%S %z').dt.date

# %%
# drop the column published date
all_news_df.drop(columns='published_date',inplace=True)

# %%
# Data set after converting the date
all_news_df.head()
# Out:
#                                                Title  \
# 0  Chinese start-up Moonshot AI raises US$1 billi...
# 1  Alibaba Stock Falls as Chinese Markets Disappo...
# 2  Big Pension Bought Up NYCB Stock Right Before ...
# 3     25 Most Valuable Tech Companies Outside The US
# 4          No Clear Sign of a Turnaround for Alibaba
#
#                                              Content Company        date
# 0  Chinese artificial intelligence start-up Moons...    BABA  2024-02-20
# 1  Shanghai stocks advanced on Monday but posted ...    BABA  2024-02-19
# 2  A New York pension bought up shares of New Yor...    BABA  2024-02-19
# 3  In this article, we will take a look at the 25...    BABA  2024-02-16
# 4  Taobao and TMall Group's troubles overshadow g...    BABA  2024-02-16

# %%
all_news_df.rename(columns={'Company':'Abbreviation'},inplace=True)

# %%
merge_data=pd.merge(all_news_df,data,on='Abbreviation')

# %% [markdown]
# ##  NLP

# %%
lemma=WordNetLemmatizer()

def text_pre_preocessing(text):
    
    token=word_tokenize(text) # convert the sentences into token
    token_without_stop=[word for word in token if word.lower() not in stopwords.words('english')] # removing the stop words

    
    
    #lemmatization
    
    lem_token=[lemma.lemmatize(token) for token in token_without_stop] # getting the real meaning word
    
    return lem_token

# %%
# titel preprocesing
merge_data['Titel_preprosses']=merge_data['Title'].apply(text_pre_preocessing)

# %%
# content preprocessing
merge_data['Content_preprosses']=merge_data['Content'].apply(text_pre_preocessing)

# %%
merge_data
# Out:
#                                                  Title  \
# 0    Chinese start-up Moonshot AI raises US$1 billi...
# 1    Alibaba Stock Falls as Chinese Markets Disappo...
# 2    Big Pension Bought Up NYCB Stock Right Before ...
# 3       25 Most Valuable Tech Companies Outside The US
# 4            No Clear Sign of a Turnaround for Alibaba
# ..                                                 ...
# 221  Country Garden to Make CNY3.07 Billion Disposa...
# 222  Country Garden sells stake in Dalian Wanda uni...
# 223  UPDATE 1-Country Garden has remitted funds to ...
# 224  Country Garden repays US$111 million bond in f...
# 225  Trending tickers: Arm | Jumia | Country Garden...
#
#                                                Content Abbreviation  \
# 0    Chinese artificial intelligence start-up Moons...         BABA
# 1    Shanghai stocks advanced on Monday but posted ...         BABA
# 2    A New York pension bought up shares of New Yor...         BABA
# 3    In this article, we will take a look at the 25...         BABA
# 4    Taobao and TMall Group's troubles overshadow g...         BABA
# ..                                                 ...          ...
# 221  Chinese property giant Country Garden will sel...      2007.HK
# 222  HONG KONG (Reuters) -China's embattled Country...      2007.HK
# 223  Embattled Chinese developer Country Garden Hol...      2007.HK
# 224  Embattled property developer Country Garden Ho...      2007.HK
# 225  The latest investor updates on stocks that are...      2007.HK
#
#            date                             Company_Name  \
# 0    2024-02-20            Alibaba Group Holding Limited
# 1    2024-02-19            Alibaba Group Holding Limited
# 2    2024-02-19            Alibaba Group Holding Limited
# 3    2024-02-16            Alibaba Group Holding Limited
# 4    2024-02-16            Alibaba Group Holding Limited
# ..          ...                                      ...
# 221  2023-12-14  Country Garden Holdings Company Limited
# 222  2023-12-14  Country Garden Holdings Company Limited
# 223  2023-12-13  Country Garden Holdings Company Limited
# 224  2023-12-13  Country Garden Holdings Company Limited
# 225  2023-11-23  Country Garden Holdings Company Limited
#
#                                       Titel_preprosses  \
# 0    [Chinese, start-up, Moonshot, AI, raise, US, $...
# 1    [Alibaba, Stock, Falls, Chinese, Markets, Disa...
# 2    [Big, Pension, Bought, NYCB, Stock, Right, Tum...
# 3         [25, Valuable, Tech, Companies, Outside, US]
# 4                   [Clear, Sign, Turnaround, Alibaba]
# ..                                                 ...
# 221  [Country, Garden, Make, CNY3.07, Billion, Disp...
# 222  [Country, Garden, sell, stake, Dalian, Wanda, ...
# 223  [UPDATE, 1-Country, Garden, remitted, fund, re...
# 224  [Country, Garden, repays, US, $, 111, million,...
# 225  [Trending, ticker, :, Arm, |, Jumia, |, Countr...
#
#                                     Content_preprosses
# 0    [Chinese, artificial, intelligence, start-up, ...
# 1    [Shanghai, stock, advanced, Monday, posted, re...
# 2    [New, York, pension, bought, share, New, York,...
# 3    [article, ,, take, look, 25, valuable, tech, c...
# 4    [Taobao, TMall, Group, 's, trouble, overshadow...
# ..                                                 ...
# 221  [Chinese, property, giant, Country, Garden, se...
# 222  [HONG, KONG, (, Reuters, ), -China, 's, embatt...
# 223  [Embattled, Chinese, developer, Country, Garde...
# 224  [Embattled, property, developer, Country, Gard...
# 225  [latest, investor, update, stock, trending, Th...
#
# [226 rows x 7 columns]

# %%
# sentiment

from textblob import TextBlob

def Sentiment_Analyze_com(preprossesd_token):
    
    
    text=" ".join(preprossesd_token)
    
    blob=TextBlob(text)
    # polarity of the text
    polarity=blob.sentiment.polarity
    
    if polarity>0:
        return 1
    elif polarity<0:
        return -1
    else:
        return 0

# %%
# titel sentiment
merge_data['titel_Sentiment']=merge_data['Titel_preprosses'].apply(Sentiment_Analyze_com)

# %%
# content sentiment
merge_data['Content_Sentiment']=merge_data['Content_preprosses'].apply(Sentiment_Analyze_com)

# %%
merge_data
# Out:
#                                                  Title  \
# 0    Chinese start-up Moonshot AI raises US$1 billi...
# 1    Alibaba Stock Falls as Chinese Markets Disappo...
# 2    Big Pension Bought Up NYCB Stock Right Before ...
# 3       25 Most Valuable Tech Companies Outside The US
# 4            No Clear Sign of a Turnaround for Alibaba
# ..                                                 ...
# 221  Country Garden to Make CNY3.07 Billion Disposa...
# 222  Country Garden sells stake in Dalian Wanda uni...
# 223  UPDATE 1-Country Garden has remitted funds to ...
# 224  Country Garden repays US$111 million bond in f...
# 225  Trending tickers: Arm | Jumia | Country Garden...
#
#                                                Content Abbreviation  \
# 0    Chinese artificial intelligence start-up Moons...         BABA
# 1    Shanghai stocks advanced on Monday but posted ...         BABA
# 2    A New York pension bought up shares of New Yor...         BABA
# 3    In this article, we will take a look at the 25...         BABA
# 4    Taobao and TMall Group's troubles overshadow g...         BABA
# ..                                                 ...          ...
# 221  Chinese property giant Country Garden will sel...      2007.HK
# 222  HONG KONG (Reuters) -China's embattled Country...      2007.HK
# 223  Embattled Chinese developer Country Garden Hol...      2007.HK
# 224  Embattled property developer Country Garden Ho...      2007.HK
# 225  The latest investor updates on stocks that are...      2007.HK
#
#            date                             Company_Name  \
# 0    2024-02-20            Alibaba Group Holding Limited
# 1    2024-02-19            Alibaba Group Holding Limited
# 2    2024-02-19            Alibaba Group Holding Limited
# 3    2024-02-16            Alibaba Group Holding Limited
# 4    2024-02-16            Alibaba Group Holding Limited
# ..          ...                                      ...
# 221  2023-12-14  Country Garden Holdings Company Limited
# 222  2023-12-14  Country Garden Holdings Company Limited
# 223  2023-12-13  Country Garden Holdings Company Limited
# 224  2023-12-13  Country Garden Holdings Company Limited
# 225  2023-11-23  Country Garden Holdings Company Limited
#
#                                       Titel_preprosses  \
# 0    [Chinese, start-up, Moonshot, AI, raise, US, $...
# 1    [Alibaba, Stock, Falls, Chinese, Markets, Disa...
# 2    [Big, Pension, Bought, NYCB, Stock, Right, Tum...
# 3         [25, Valuable, Tech, Companies, Outside, US]
# 4                   [Clear, Sign, Turnaround, Alibaba]
# ..                                                 ...
# 221  [Country, Garden, Make, CNY3.07, Billion, Disp...
# 222  [Country, Garden, sell, stake, Dalian, Wanda, ...
# 223  [UPDATE, 1-Country, Garden, remitted, fund, re...
# 224  [Country, Garden, repays, US, $, 111, million,...
# 225  [Trending, ticker, :, Arm, |, Jumia, |, Countr...
#
#                                     Content_preprosses  titel_Sentiment  \
# 0    [Chinese, artificial, intelligence, start-up, ...                1
# 1    [Shanghai, stock, advanced, Monday, posted, re...                1
# 2    [New, York, pension, bought, share, New, York,...                1
# 3    [article, ,, take, look, 25, valuable, tech, c...                0
# 4    [Taobao, TMall, Group, 's, trouble, overshadow...                1
# ..                                                 ...              ...
# 221  [Chinese, property, giant, Country, Garden, se...                0
# 222  [HONG, KONG, (, Reuters, ), -China, 's, embatt...                0
# 223  [Embattled, Chinese, developer, Country, Garde...                1
# 224  [Embattled, property, developer, Country, Gard...                1
# 225  [latest, investor, update, stock, trending, Th...                0
#
#      Content_Sentiment
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                   -1
# ..                 ...
# 221                 -1
# 222                 -1
# 223                 -1
# 224                  1
# 225                  1
#
# [226 rows x 9 columns]

# %%
merge_data.drop(columns=['Titel_preprosses','Content_preprosses'],inplace=True)

# %%
# Exporting the dataset
merge_data.to_csv('China_dataset1.csv')

# %%
merge_data
# Out:
#                                                  Title  \
# 0    Chinese start-up Moonshot AI raises US$1 billi...
# 1    Alibaba Stock Falls as Chinese Markets Disappo...
# 2    Big Pension Bought Up NYCB Stock Right Before ...
# 3       25 Most Valuable Tech Companies Outside The US
# 4            No Clear Sign of a Turnaround for Alibaba
# ..                                                 ...
# 221  Country Garden to Make CNY3.07 Billion Disposa...
# 222  Country Garden sells stake in Dalian Wanda uni...
# 223  UPDATE 1-Country Garden has remitted funds to ...
# 224  Country Garden repays US$111 million bond in f...
# 225  Trending tickers: Arm | Jumia | Country Garden...
#
#                                                Content Abbreviation  \
# 0    Chinese artificial intelligence start-up Moons...         BABA
# 1    Shanghai stocks advanced on Monday but posted ...         BABA
# 2    A New York pension bought up shares of New Yor...         BABA
# 3    In this article, we will take a look at the 25...         BABA
# 4    Taobao and TMall Group's troubles overshadow g...         BABA
# ..                                                 ...          ...
# 221  Chinese property giant Country Garden will sel...      2007.HK
# 222  HONG KONG (Reuters) -China's embattled Country...      2007.HK
# 223  Embattled Chinese developer Country Garden Hol...      2007.HK
# 224  Embattled property developer Country Garden Ho...      2007.HK
# 225  The latest investor updates on stocks that are...      2007.HK
#
#            date                             Company_Name  titel_Sentiment  \
# 0    2024-02-20            Alibaba Group Holding Limited                1
# 1    2024-02-19            Alibaba Group Holding Limited                1
# 2    2024-02-19            Alibaba Group Holding Limited                1
# 3    2024-02-16            Alibaba Group Holding Limited                0
# 4    2024-02-16            Alibaba Group Holding Limited                1
# ..          ...                                      ...              ...
# 221  2023-12-14  Country Garden Holdings Company Limited                0
# 222  2023-12-14  Country Garden Holdings Company Limited                0
# 223  2023-12-13  Country Garden Holdings Company Limited                1
# 224  2023-12-13  Country Garden Holdings Company Limited                1
# 225  2023-11-23  Country Garden Holdings Company Limited                0
#
#      Content_Sentiment
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                   -1
# ..                 ...
# 221                 -1
# 222                 -1
# 223                 -1
# 224                  1
# 225                  1
#
# [226 rows x 7 columns]

# %%
remaining_company_names.count()
# Out:
# Company_Name    33
# Abbreviation    33
# dtype: int64

# %%
remaining_company_names = data[~data['Company_Name'].isin(merge_data['Company_Name'])]
remaining_company_names
# Out:
#                                         Company_Name     Abbreviation
# 2            China Mobile Communications Corporation              CHL
# 5         Ping An Insurance (Group) Company of China       Ltd.,PNGAY
# 6                            Huawei Technologies Co.   Ltd.,002502.SZ
# 7                                             JD.com          Inc.,JD
# 8               China National Petroleum Corporation              SNP
# 9                                      Sinopec Group              SHI
# 10  China State Construction Engineering Corporation        601668.SS
# 11              China Life Insurance Company Limited              LFC
# 12                          China Merchants Bank Co.   Ltd.,600036.SS
# 14                                   China Resources         00291.HK
# 17                               Wuliangye Yibin Co.   Ltd.,000858.SZ
# 19               China Pacific Insurance (Group) Co.   Ltd.,601601.SS
# 20                 China Telecom Corporation Limited              CHA
# 23                                             Baidu        Inc.,BIDU
# 24                           China Yangtze Power Co.   Ltd.,600900.SS
# 25                                   China Vanke Co.     Ltd.,2202.HK
# 26           China Southern Airlines Company Limited              ZNH
# 27                  China Unicom (Hong Kong) Limited              CHU
# 30           China National Offshore Oil Corporation              CEO
# 31                                   Midea Group Co.   Ltd.,000333.SZ
# 32                       China Minmetals Corporation        600058.SS
# 33                               China Huaneng Group        600011.SS
# 34                             China Merchants Group        001979.SZ
# 37  China Taiping Insurance Holdings Company Limited         00966.HK
# 38           China General Nuclear Power Corporation        601985.SS
# 40               China Energy Investment Corporation        601699.SS
# 41                          CRRC Corporation Limited          1766.HK
# 43                        Bank of Communications Co.     Ltd.,3328.HK
# 44              China Pacific Construction Group Co.   Ltd.,601186.SS
# 46                China Fortune Land Development Co.   Ltd.,600340.SS
# 47                     China Southern Power Grid Co.   Ltd.,600028.SS
# 48  China National Building Material Company Limited          3323.HK
# 49               China Jinmao Holdings Group Limited         00817.HK

# %%
log(3/2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 log(3/2)
#
# NameError: name 'log' is not defined
